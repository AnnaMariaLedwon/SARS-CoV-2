# %%
# Load Data from https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/virus?SeqType_s=Nucleotide&VirusLineage_ss=Wuhan%20seafood%20market%20pneumonia%20virus,%20taxid:2697049&utm_source=gquery&utm_medium=referral&utm_campaign=COVID-19
# https://www.ncbi.nlm.nih.gov/

import pandas as pd
import numpy as np

seq_df = pd.read_csv('C:\PythonScripts\Database-for-projects\SARS-CoV-2\sequences.csv')

# %%
seq_df.head()
# Out:
#    Accession SRA_Accession          Release_Date  \
# 0  NC_045512           NaN  2020-01-13T00:00:00Z
# 1   LC581364           NaN  2020-10-14T00:00:00Z
# 2   LC581365           NaN  2020-10-14T00:00:00Z
# 3   LC581366           NaN  2020-10-14T00:00:00Z
# 4   LC581367           NaN  2020-10-14T00:00:00Z
#
#                                              Species            Genus  \
# 0  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 1  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 2  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 3  Severe acute respiratory syndrome-related coro...  Betacoronavirus
# 4  Severe acute respiratory syndrome-related coro...  Betacoronavirus
#
#           Family  Length Sequence_Type Nuc_Completeness  Genotype  Segment  \
# 0  Coronaviridae   29903        RefSeq         complete       NaN      NaN
# 1  Coronaviridae   29888       GenBank          partial       NaN      NaN
# 2  Coronaviridae   29900       GenBank          partial       NaN      NaN
# 3  Coronaviridae   29897       GenBank          partial       NaN      NaN
# 4  Coronaviridae   29891       GenBank          partial       NaN      NaN
#
#                                              Authors  \
# 0  Wu,F., Zhao,S., Yu,B., Chen,Y.M., Wang,W., Son...
# 1  Asakura,H., Yoshida,I., Kumagai,R., Nagashima,...
# 2  Asakura,H., Yoshida,I., Kumagai,R., Nagashima,...
# 3  Asakura,H., Yoshida,I., Kumagai,R., Nagashima,...
# 4  Asakura,H., Yoshida,I., Kumagai,R., Nagashima,...
#
#                              Publications Geo_Location  USA          Host  \
# 0  32015508, 15680415, 15630477, 10482585        China  NaN  Homo sapiens
# 1                                     NaN        Japan  NaN  Homo sapiens
# 2                                     NaN        Japan  NaN  Homo sapiens
# 3                                     NaN        Japan  NaN  Homo sapiens
# 4                                     NaN        Japan  NaN  Homo sapiens
#
#   Isolation_Source Collection_Date BioSample  \
# 0              NaN         2019-12       NaN
# 1              NaN         2020-03       NaN
# 2              NaN         2020-03       NaN
# 3              NaN         2020-03       NaN
# 4              NaN         2020-03       NaN
#
#                                        GenBank_Title
# 0  Severe acute respiratory syndrome coronavirus ...
# 1  Severe acute respiratory syndrome coronavirus ...
# 2  Severe acute respiratory syndrome coronavirus ...
# 3  Severe acute respiratory syndrome coronavirus ...
# 4  Severe acute respiratory syndrome coronavirus ...

# %%
seq_df['Geo_Location'].unique()
# Out:
# array(['China', 'Japan', nan, 'Iran', 'USA: TX', 'Sweden', 'USA',
#        'USA: Minnesota', 'USA: Washington', 'USA: Washington,King County',
#        'Malta', 'Malaysia: Pahang, Kuantan', 'Egypt', 'USA: Ak',
#        'USA: Oklahoma', 'USA: New Mexico', 'USA: AL', 'USA: AR',
#        'USA: AZ', 'USA: CA', 'USA: FL', 'USA: IL', 'USA: MI', 'USA: WA',
#        'USA: CT', 'USA: HI', 'USA: LA', 'USA: NV', 'USA: OK', 'USA: WI',
#        'USA: GA', 'USA: ID', 'USA: KS', 'USA: MA', 'USA: ME', 'USA: MO',
#        'USA: NH', 'USA: CO', 'USA: MN', 'USA: NY', 'USA: IN', 'USA: NJ',
#        'USA: OH', 'USA: CB', 'USA: MS', 'USA: PR', 'USA: TN', 'USA: WY',
#        'USA: OR', 'USA: PA', 'USA: UT', 'USA: WV', 'USA: Virginia',
#        'USA: SC, GEORGETOWN', 'USA: SC, HORRY', 'USA: SC, WILLIAMSBURG',
#        'Spain', 'USA: MD', 'USA: Georgia', 'USA: Florida',
#        'USA: Texas, Galveston', 'United Kingdom', 'Venezuela', 'France',
#        'USA: Wyoming', 'USA: Wisconsin, Dane county',
#        'USA: Wisconsin, Marquette county', 'USA: Wisconsin, Green county',
#        'USA: Wisconsin, Lafayette county', 'USA: Wisconsin, Dodge county',
#        'USA: Wisconsin, Sauk county', 'USA: Wisconsin, Iowa county',
#        'USA: Wisconsin, Milwaukee county', 'USA: Wisconsin, Rock county',
#        'USA: Wisconsin, Columbia county',
#        'USA: Wisconsin, Jefferson county', 'USA: New York, Nassau county',
#        'USA: California, San Diego county',
#        'USA: Wisconsin, Adams county',
#        'USA: California, Los Angeles county', 'USA: Nevada, Clark county',
#        'USA: Wisconsin, Brown county', 'USA: Wisconsin, Monroe county',
#        'USA: New York, New York county',
#        'USA: New York, Westchester county',
#        'USA: New Jersey, Morris county', 'USA: Wisconsin, Lincoln county',
#        'USA: Illinois, Cook county', 'USA: New York, Putnam county',
#        'USA: Missouri, Saint Louis county',
#        'USA: Wisconsin, Sheboygan county',
#        'USA: Wisconsin, Marathon county', 'USA: CA, Orange County',
#        'USA: CA, Santa Clara County', 'USA: CA, Sonoma County',
#        'USA: CA, San Francisco County', 'USA: CA, Marin County',
#        'USA: CA, Humboldt County', 'Peru',
#        'USA: Illinois, Winnebago county',
#        'USA: Wisconsin, Waukesha county',
#        'USA: Wisconsin, Outagamie county',
#        'USA: Wisconsin, Portage county',
#        'USA: Wisconsin, Richland county',
#        'USA: Wisconsin, Fond du Lac county',
#        'USA: Wisconsin, Grant county', 'USA: Wisconsin, Walworth county',
#        'USA: Illinois, Boone county', 'Pakistan', 'India: Delhi',
#        'India: Uttar Pradesh', 'India: Telangana', 'USA: SC, DU BOIS',
#        'Puerto Rico', 'Serbia', 'USA: SC, Beaufort',
#        'China: Hunan,Huaihua', 'China: Hunan,Shaoyang',
#        'Italy: Lombardia, Milan',
#        'USA: Pennsylvania, Philadelphia county', 'USA: SC, LORIS',
#        'USA: SC, NORTH HORRY', 'USA: MD, THURMONT', 'USA: NM',
#        'USA: North Carolina', 'Egypt: Cairo', 'USA: MA, WORCSTER (HORRY)',
#        'USA: SC, MARION', 'India: Modasa', 'India: Ahmedabad',
#        'Australia: Victoria', 'Australia: Northern Territory',
#        'Australia: Tasmania', 'India: Vadodara', 'India: Patan',
#        'India: Khambhaliya', 'India: Gandhinagar', 'India: Mansa',
#        'India: Jamnagar', 'Turkey', 'Tunisia', 'India: Siddhpur', 'Italy',
#        'India: Kalol', 'India: Daskroi', 'India: Dhandhuka',
#        'India: Dahegam', 'Germany', 'India: Adajan', 'India: Mehsana',
#        'Iraq', 'Italy: Milan', 'Italy: Turin', 'Italy: Bologna',
#        'USA: DC, District of Columbia county',
#        'USA: Wisconsin, Racine county',
#        'USA: Pennsylvania, Allegheny county',
#        'USA: Wisconsin, Eau Claire county',
#        'USA: Illinois, Jo Daviess county',
#        'USA: Minnesota, Houston county',
#        'USA: Illinois, Stephenson county', 'Italy: Rome', 'Denmark',
#        'Philippines: National Capital Region, Makati City',
#        'Philippines: NCR, Quezon City', 'Philippines: NCR, Taguig City',
#        'Philippines: NCR, Pasay City', 'Philippines: NCR, Cavite City',
#        'Philippines: Region 4A (Laguna), Calamba City',
#        'Philippines: NCR, Caloocan City',
#        'Philippines: Region 4A (Rizal), Rodriguez',
#        'Philippines: NCR, San Juan City',
#        'Philippines: Region 3 (Bulacan), San Jose del Monte City',
#        'India: Kerala State', 'Ghana', 'Russia: Moscow', 'China: Beijing',
#        'Serbia: Uzice', 'Serbia: Kraljevo', 'Serbia: Novi Pazar',
#        'USA: Maine', 'USA: New York', 'USA: Connecticut', 'Russia',
#        'USA: Massachusetts', 'USA: New Hampshire',
#        'Iraq: Kuedistan region, Erbil', 'Bangladesh', 'Sierra Leone',
#        'Sierra Leone: Freetown', 'Sierra Leone: Bonthe', 'USA: AK',
#        'Cuba', 'USA: SC', 'USA: Wisconsin, Ozaukee county',
#        'USA: Wisconsin, Washington county',
#        'USA: South Dakota, Minnehaha county',
#        'USA: Ohio, Cuyahoga county', 'USA: Wisconsin', 'Brazil', 'Belize',
#        'Guatemala', 'USA: Washington,Yakima County',
#        'USA: Washington,Benton County', 'USA: Washington,Pierce County',
#        'USA: Washington,Kittitas County',
#        'USA: Washington,Franklin County',
#        'USA: Washington,Whatcom County', 'USA: Washington,Spokane County',
#        'USA: Washington,Asotin County',
#        'USA: Washington,Snohomish County',
#        'USA: California,Los Angeles County',
#        'USA: Washington,Thurston County',
#        'USA: Washington,Cowlitz County',
#        'USA: Washington,Grays Harbor County',
#        'USA: Washington,Mason County', 'Georgia', 'Germany: Bavaria',
#        'USA: Washington,Walla Walla County',
#        'USA: Washington,Skagit County', 'USA: Washington,Chelan County',
#        'USA: Alabama, Mobile county', 'Saudi Arabia',
#        'USA: San Diego, California', 'USA: Cruise_Ship_1, California',
#        'USA: Cruise_Ship_2, California', 'USA: Imperial, California',
#        'Mexico: Tijuana, BajaCalifornia', 'Jordan: Amman',
#        'Jordan: Irbid', 'USA: New Orleans, Louisiana', 'India: Surat',
#        'USA: IA', 'USA: NC', 'India: Dholka', 'India: Ghogha',
#        'India: Mahuva', 'India: Kamrej', 'India: Chorasi',
#        'India: Nadiad', 'India: Kheda', 'India: Botad', 'India: Mandvi',
#        'India: Prantij', 'Lebanon', 'India',
#        'USA: New Jersey, Burlington county',
#        'USA: South Carolina, Ridgeway', 'USA: South Carolina, Kershaw',
#        'USA: South Carolina, Richland', 'Bahrain', 'Zambia', 'Thailand',
#        'Poland', 'USA: South Carolina, Fairfield', 'India: Himatnagar',
#        'India: Choryasi', 'USA: Illinois, Kane county',
#        'USA: Massachusetts, Middlesex county',
#        'USA: Massachusetts, Norfolk county',
#        'USA: New York, Rockland county', 'USA: New Jersey, Essex county',
#        'USA: California, Santa Clara county',
#        'USA: Arizona, Maricopa county', 'USA: Iowa, Jackson county',
#        'USA: Florida, Miami-dade county',
#        'USA: Minnesota, Stearns county', 'USA: Illinois, Lake county',
#        'USA: Illinois, Dupage county', 'USA: Colorado, Denver county',
#        'USA: Florida, Palm Beach county', 'USA: Arkansas, Little Rock',
#        'India: Rajkot', 'India: Jetpur', 'Bangladesh: Jashore',
#        'Bangladesh: Khulna', 'USA: South Carolina, Berkeley',
#        'Bangladesh: Barishal', 'Australia: South Australia', 'Belgium',
#        'USA: Wisconsin, Manitowoc county',
#        'USA: Wisconsin, Jackson county',
#        'USA: Wisconsin, Trempealeau county',
#        'USA: Connecticut, Fairfield county',
#        'USA: Wisconsin, Vernon county', 'USA: Illinois, Mchenry county',
#        'USA: Pennsylvania, Montgomery county',
#        'USA: New Jersey, Bergen county', 'USA: New York, Onondaga county',
#        'USA: Wisconsin, Winnebago county', 'USA: Wisconsin, Door county',
#        'Iran: Hamadan', 'Iran: hamadan', 'India: Talod', 'India: Chuda',
#        'India: Junagadh', 'India: Gondal', 'India: Olpad', 'South Korea',
#        'Morocco', 'Bahrain: Capital', 'Viet Nam', 'USA: CA, Alameda',
#        'Mexico: Mexico City', 'Mexico: Mexico State', 'Mexico: Queretaro',
#        'Mexico: Michoacan', 'Mexico: Baja California Sur',
#        'Mexico: Puebla', 'Mexico: Hidalgo', 'Mexico: Oaxaca',
#        'Mexico: Morelos', 'New Zealand', 'USA: Wisconsin, Dane County',
#        'USA: Wisconsin, Chippewa county', 'USA: Colorado, El Paso county',
#        'USA: Iowa, Dubuque county', 'USA: Illinois, Winnebago County',
#        'Netherlands', 'India: Savali', 'India: Palanpur',
#        'India: Bardoli', 'India: Kapadvanj', 'Chile', 'Bangladesh: Dhaka',
#        'Bangladesh: Rangpur', 'Bangladesh: Chattogram', 'India: Bharuch',
#        'India: Savli', 'India: Bhuj', 'Spain: Donostia-San Sebatian',
#        'USA: DC', 'USA: Maryland', 'USA: Washington,Jefferson County',
#        'USA: Washington,Adams County', 'Timor-Leste',
#        'USA: Washington, Yakima County', 'USA: Washington, King County',
#        'USA: Washington, Snohomish County',
#        'USA: Washington, Skagit County', 'USA: Washington, Pierce County',
#        'USA: Washington, Asotin County',
#        'USA: Washington, Douglas County', 'USA: Washington, Adams County',
#        'USA: Washington, Spokane County',
#        'USA: Washington, Cowlitz County',
#        'USA: Washington, Benton County', 'USA: Washington, Grant County',
#        'USA: Washington, Franklin County',
#        'USA: Washington, Mason County',
#        'USA: California, Monterey County', 'Hong Kong',
#        'India: Gujarat, Ahmedabad', 'India: Gujarat, Vadodara',
#        'India: Gujarat, Nadiad', 'Russia: Moscow region',
#        'India: Gujarat, Mahemdavad', 'India: Gujarat, Dhanera',
#        'USA: Washington,Grant County', 'USA: Washington,Umatilla County',
#        'USA: Washington,Clark County', 'Saudi Arabia: Jeddah', 'USA: KY',
#        'USA: Maricopa County, Arizona', 'USA: Maricopa Country, Arizona',
#        'Bangladesh: Narayanganj', 'India: Kadi', 'USA: King County,WA',
#        'USA: Snohomish County,WA', 'Taiwan', 'USA: Michigan',
#        'Germany: Dusseldorf', 'Germany: Heinsberg', 'Spain: ASTURIAS',
#        'Nigeria', 'Japan:Tokyo', 'China: Guangzhou',
#        'Morocco: Casablanca', 'Serbia: Novi Sad', 'India: Khedbrahma',
#        'India: Bayad', 'Tunisia: Bizerte', 'Tunisia: Ben Arous', 'Kenya',
#        'China: Zhejiang', 'Czech Republic', 'China: Jiangsu, Changzhou',
#        'USA: NAPOLEONVILLE, LA', 'USA: New Orleans, LA',
#        'USA: LACOMBE, LA', 'USA: MARRERO, LA', 'USA: METAIRIE, LA',
#        'USA: CHALMETTE, LA', 'USA: VIOLET, LA', 'USA: SLIDELL, LA',
#        'USA: HAMMOND, LA', 'USA: KENNER, LA', 'USA: AVONDALE, LA',
#        'Italy: Lazio', 'Netherlands: Leiden', 'India: Dahod',
#        'India: Kodinar', 'India: Una', 'USA: Ohio',
#        'USA: Oregon, Wisconsin', 'USA: Dane County, Wisconsin',
#        'USA: Illinois', 'USA: Madison, Wisconsin',
#        'USA: Mount Horeb, Wisconsin', 'USA: Verona, Wisconsin', 'Jamaica',
#        'Pakistan: Karachi', 'USA: VA', 'Japan:Kochi', 'Japan:Chiba',
#        'Japan:Ishikawa', 'Japan:Saitama', 'USA: VT', 'Uruguay',
#        'India: Dhansura', 'Colombia', 'Greece: Athens', 'Guam',
#        'Italy: Palermo', 'India: Hyderabad',
#        'China: Guangdong, Guangzhou', 'USA: MARINGOUIN, LA',
#        'USA: KILLONA, LA', 'USA: SAINT ROSE, LA', 'USA: LOCKPORT, LA',
#        'USA: NEW ORLEANS, LA', 'USA: LULING, LA', 'USA: RACELAND, LA',
#        'USA: GRAY, LA', 'USA: GHEENS, LA', 'USA: THIBODAUX,LA',
#        'USA: Slidell, LA', 'USA: Lacombe, LA', 'USA: HOUMA, LA',
#        'USA: SLIDELL LA', 'USA: DELACROIX, LA', 'Uzbekistan',
#        'Kazakhstan', 'India: Assam, Golaghat',
#        'USA: East Feliciana Parish, Louisiana', 'Netherlands: Milheeze',
#        'Sri Lanka', 'Malaysia', 'China: Nanchang', 'USA: RI',
#        'South Africa: KwaZulu-Natal', 'USA: NE', 'Greece',
#        'Tunisia: Tunis', 'China: Anhui, Fuyang', 'China: Wuhan', 'Israel',
#        'Pakistan: KPK', 'Spain: Valencia', 'Colombia: Antioquia',
#        'USA: San Francisco, CA', 'China: Hubei, Wuhan',
#        'China: Zhejiang, Hangzhou', 'Pakistan: Gilgit', 'Italy: Cagliari',
#        'USA: CA, San Diego County', 'Viet Nam: Ho Chi Minh city',
#        'Iran: Tehran', 'Iran: Qum', 'China: Shanghai', 'Nigeria: Lagos',
#        'USA: Snohomish County, WA', 'Australia: Queensland',
#        'China: HuaShang', 'Nepal', 'Philippines', 'China: Yunnan',
#        'Australia', 'China: Hangzhou', 'Finland', 'China:Wuhan',
#        'Australia: Melbourne, Victoria', 'China: Shenzhen'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,4))
plot = sns.countplot(seq_df['Geo_Location'])
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, ha='right')
plt.show()
